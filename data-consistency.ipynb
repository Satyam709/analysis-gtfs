# %%
import pandas as pd
# Load the data
trips = pd.read_csv('data/trips.txt')
routes = pd.read_csv('data/routes.txt')
stops = pd.read_csv('data/stops.txt')
stop_times = pd.read_csv('data/stop_times.txt')
calendar = pd.read_csv('data/calendar.txt')
calendar_dates = pd.read_csv('data/calendar_dates.txt')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 routes = pd.read_csv('data/routes.txt')
#       5 stops = pd.read_csv('data/stops.txt')
# ----> 6 stop_times = pd.read_csv('data/stop_times.txt')
#       7 calendar = pd.read_csv('data/calendar.txt')
#       8 calendar_dates = pd.read_csv('data/calendar_dates.txt')
#
# ...

# %%
# find schedule for trip 630242838

stop_times[stop_times['trip_id'] == 664282428 ]
# Out:
#           trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 399580  664282428     07:08:00       07:08:00    64593              1
# 399581  664282428     07:09:21       07:09:21    64569             24
# 399582  664282428     07:10:09       07:10:09    64451             41
# 399583  664282428     07:11:01       07:11:01    64582             75
# 399584  664282428     07:11:28       07:11:28    64559             80
# 399585  664282428     07:12:08       07:12:08    64568             90
# 399586  664282428     07:12:57       07:12:57    64554             97
# 399587  664282428     07:13:13       07:13:13    64456            100
# 399588  664282428     07:13:29       07:13:29    81692            104
# 399589  664282428     07:13:55       07:13:55    65090            110
# 399590  664282428     07:14:29       07:14:29    80486            116
# 399591  664282428     07:15:00       07:15:00    64512            122
# ...

# %%
calendar_dates[calendar_dates['service_id'] == 1746057300000]
